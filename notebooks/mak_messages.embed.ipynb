# %% [markdown]
# # Clean up indiviudal messagers
#
# Coco Yu
# August 19, 2024
#
# ## Code Status
#
# ## Setup
#
# Chunk Defaults

# %%
knitr::opts_chunk$set(attr.output='style="max-height: 500px;"')

# %% [markdown]
# Conflicts

# %%
options(conflicts.policy = "depends.ok")

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# here() starts at C:/Users/jyu274/Desktop/github/study_messages

# %% [markdown]
# Source Functions

# %%
devtools::source_url("https://github.com/jjcurtin/lab_support/blob/main/format_path.R?raw=true")
# Out:
# ℹ SHA-1 hash of file is "a58e57da996d1b70bb9a5b58241325d6fd78890f"
# ℹ SHA-1 hash of file is "c045eee2655a18dc85e715b78182f176327358a7"
# ℹ SHA-1 hash of file is "def6ce26ed7b2493931fde811adff9287ee8d874"

# %% [markdown]
# Absolute Paths

# %%
path_shared <- format_path(str_c("studydata/risk/data_processed/shared"))

# %% [markdown]
# ## Read in Data

# %%
data <- read_csv(here(path_shared, "sms.csv"), 
                 col_types = cols(
                   subid = "d", start_study = "T", end_study = "T",
                   address = "c", date = "T", type = "f", body = "c",
                   msg_type = "f", phone_type = "f"
                 )) |> 
  glimpse()
# Out:
# Rows: 431,519
# Columns: 9
# $ subid       <dbl> 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2…
# $ start_study <dttm> 2017-03-02, 2017-03-02, 2017-03-24, 2017-03-24, 2017-03-2…
# $ end_study   <dttm> 2017-05-31, 2017-05-31, 2017-06-16, 2017-06-16, 2017-06-1…
# $ address     <chr> "16085720721", "16085722496", "16086098891", "16086098891"…
# $ date        <dttm> 2017-05-01 14:35:14, 2017-04-21 22:01:40, 2017-03-24 01:3…
# $ type        <fct> received, received, sent, received, received, received, se…
# $ body        <chr> "Test", "Test Message Please type YES if you receive this …
# $ msg_type    <fct> imessage, imessage, sms, sms, sms, sms, sms, sms, sms, sms…
# $ phone_type  <fct> ios, ios, android, android, android, android, android, and…

# %% [markdown]
# ## Data Cleaning
#
# check format of address in contacts.csv

# %%
nchar(contacts$phone_number) |> 
  tabyl()
# Out:
#  nchar(contacts$phone_number)    n      percent valid_percent
#                             5   13 0.0017560448  0.0017562821
#                             6    7 0.0009455626  0.0009456904
#                             7    1 0.0001350804  0.0001350986
#                            10 7364 0.9947318655  0.9948662524
#                            12   17 0.0022963663  0.0022966766
#                            NA    1 0.0001350804            NA
#     subid          utc                 contact_type     phone_type   phone_number     contact_drank_past   drink_status   contact_drink_future    recovery   support_status   contact_experience   monthly_visit       street_address      city   state   digits
#   ------- ------------ ---------------------------- -------------- -------------- ---------------------- -------------- ---------------------- ----------- ---------------- -------------------- --------------- -------------------- --------- ------- --------
#        21   1508767320              Irrelevant/Spam   other_phone1          21525                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#        21   1508767320              Irrelevant/Spam   other_phone1          67283                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#        21   1508767320              Irrelevant/Spam   other_phone1          89289                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#        30   1510779600              Irrelevant/Spam     cell_phone          67578                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#        58   1524519000              Irrelevant/Spam   other_phone1          21525                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#        76   1530126000              Irrelevant/Spam   other_phone1          77887                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#        76   1530126000              Irrelevant/Spam   other_phone1          89885                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#        85   1531334400              Irrelevant/Spam   other_phone1          71976                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#       110   1534531200              Irrelevant/Spam   other_phone1          21525                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#       158   1544045400              Irrelevant/Spam   other_phone1          21525                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#       166   1549648800              Irrelevant/Spam   other_phone1          89289                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#       179   1550160900              Irrelevant/Spam   other_phone1          67587                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#       243   1561993200              Irrelevant/Spam   other_phone1          47272                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        5
#        30   1510779600              Irrelevant/Spam     cell_phone         262966                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        6
#        34   1512593520              Irrelevant/Spam     cell_phone         622622                     NA             NA                     NA          NA               NA                   NA              No                   NA        NA      NA        6
#        76   1530126000              Irrelevant/Spam   other_phone1         622622                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        6
#       110   1534531200              Irrelevant/Spam   other_phone1         622622                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        6
#       234   1560283200              Irrelevant/Spam   other_phone1         288472                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        6
#       243   1561993200              Irrelevant/Spam   other_phone1         692632                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        6
#       255   1564583400                        Other   other_phone1         622622                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        6
#        33   1519146600              Irrelevant/Spam     cell_phone        1113114                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA        7
#         1   1487871000                         Self     cell_phone     6083588174                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA       10
#         1   1487871000                       Parent     home_phone     6082227282     Never/Almost Never        Drinker                    Yes          No       Supportive                Mixed              NA                   NA        NA      NA       10
#         1   1487871000                        Other     cell_phone     6085149557     Never/Almost Never     NonDrinker                     No         Yes          Neutral                Mixed              NA                   NA        NA      NA       10
#         1   1487871000                       Friend     cell_phone     6084385017     Never/Almost Never     NonDrinker                     No   Dont Know       Supportive             Pleasant              NA                   NA        NA      NA       10
#         1   1487871000   Co-Worker/Business Contact     cell_phone     6082131910     Never/Almost Never      Dont Know                     No         Yes       Supportive             Pleasant              NA                   NA        NA      NA       10
#         1   1487871000                      Sibling     cell_phone     6082205506           Occasionally        Drinker                    Yes          No       Supportive             Pleasant              NA                   NA        NA      NA       10
#         1   1487871000                      Sibling     cell_phone     6087125499     Never/Almost Never        Drinker                    Yes          No            Mixed           Unpleasant              NA                   NA        NA      NA       10
#         1   1487871000                        Other     cell_phone     6085091830     Never/Almost Never     NonDrinker                     No   Dont Know       Supportive             Pleasant              NA                   NA        NA      NA       10
#         1   1487871000                        Other     cell_phone     6082138880           Occasionally        Drinker                    Yes          No       Supportive                Mixed              NA                   NA        NA      NA       10
#         2   1490281200                         Self     cell_phone     6085134796                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA       10
#         2   1490281200     Spouse/Significant Other     cell_phone     6084696114     Never/Almost Never     NonDrinker                     No          No       Supportive             Pleasant              NA                   NA        NA      NA       10
#         2   1490281200                       Parent     cell_phone     6084388784     Never/Almost Never     NonDrinker                     No          No       Supportive             Pleasant              NA                   NA        NA      NA       10
#         2   1490281200                       Friend     cell_phone     6082099771   Almost Always/Always        Drinker                     No          No       Supportive             Pleasant              NA                   NA        NA      NA       10
#         2   1490281200                       Friend     cell_phone     6082286655     Never/Almost Never        Drinker                    Yes          No     Unsupportive                Mixed              NA                   NA        NA      NA       10
#         2   1490281200                       Friend     cell_phone     6084454994           Occasionally     NonDrinker                     No         Yes       Supportive           Unpleasant              NA                   NA        NA      NA       10
#         2   1490281200                        Child     cell_phone     6082175536     Never/Almost Never     NonDrinker                     No          No       Supportive           Unpleasant              NA                   NA        NA      NA       10
#         2   1490281200                 Family-Other     cell_phone     6086098891     Never/Almost Never     NonDrinker                     No          No          Neutral             Pleasant              NA                   NA        NA      NA       10
#         2   1490281200   Co-Worker/Business Contact     cell_phone     6082209287     Never/Almost Never        Drinker                     No          No       Supportive             Pleasant              NA                   NA        NA      NA       10
#         2   1490281200                        Child     cell_phone     6082125911     Never/Almost Never     NonDrinker                     No          No       Supportive                Mixed              NA                   NA        NA      NA       10
#         2   1490281200                        Other     cell_phone     6086300368     Never/Almost Never     NonDrinker                     No          No          Neutral             Pleasant              NA                   NA        NA      NA       10
#        94   1535126400     Spouse/Significant Other     cell_phone   573153065078     Never/Almost Never        Drinker                    Yes          No       Supportive             Pleasant              No                   NA        NA      NA       12
#       117   1535576400                       Parent     cell_phone   917838348876     Never/Almost Never     NonDrinker                     No          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1535576400   Social Worker/Case Manager     cell_phone   919811021816     Never/Almost Never     NonDrinker                     No          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000   Co-Worker/Business Contact     cell_phone   918861744325     Never/Almost Never     NonDrinker                     No          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000                       Parent     cell_phone   919811789353     Never/Almost Never        Drinker                     No         Yes        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000              Irrelevant/Spam   other_phone1   914461229000                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA       12
#       117   1538685000                       Friend     cell_phone   919650630332     Never/Almost Never        Drinker              Uncertain          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000                 Family-Other     cell_phone   919654274797           Occasionally        Drinker                    Yes          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000   Co-Worker/Business Contact     cell_phone   919933112838     Never/Almost Never        Drinker              Uncertain          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000   Co-Worker/Business Contact     cell_phone   919572158706     Never/Almost Never     NonDrinker                     No          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000                        Other     cell_phone   919980224137     Never/Almost Never      Dont Know              Uncertain   Dont Know        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000                       Friend     cell_phone   919611399594     Never/Almost Never        Drinker                    Yes          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1538685000   Co-Worker/Business Contact     cell_phone   919685004720     Never/Almost Never     NonDrinker                     No          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1541703600                       Friend     cell_phone   919990723933     Never/Almost Never     NonDrinker                     No          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       117   1541703600                   Aunt/Uncle     cell_phone   919811021816     Never/Almost Never     NonDrinker                     No          No       Supportive             Pleasant              No                   NA        NA      NA       12
#       117   1541703600                       Friend     cell_phone   918800298233     Never/Almost Never        Drinker                    Yes          No        Dont Know             Pleasant              No                   NA        NA      NA       12
#       166   1549648800              Irrelevant/Spam   other_phone1   800050001020                     NA             NA                     NA          NA               NA                   NA              NA                   NA        NA      NA       12
#        81   1530117000     Spouse/Significant Other     cell_phone             NA           Occasionally        Drinker                     No          No       Supportive             Pleasant             Yes   1100 One Mile Road   Thomson      IL       NA

# %% [markdown]
# make address format consistent across contacts and data

# %%
contacts <- contacts |> 
  mutate(
    phone_number = if_else(
      nchar(phone_number) == 10,
      paste0("1", phone_number),
      phone_number
    )
  )

# %% [markdown]
# combine data and contacts

# %%
data <- contacts |> 
  group_by(subid) |> 
  summarize(freq_contacts = list(phone_number)) |>
  right_join(data, by = "subid") |> 
  glimpse()
# Out:
# Rows: 431,519
# Columns: 10
# $ subid         <dbl> 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,…
# $ freq_contacts <list> <"16083588174", "16082227282", "16085149557", "16084385…
# $ start_study   <dttm> 2017-03-02, 2017-03-02, 2017-03-24, 2017-03-24, 2017-03…
# $ end_study     <dttm> 2017-05-31, 2017-05-31, 2017-06-16, 2017-06-16, 2017-06…
# $ address       <chr> "16085720721", "16085722496", "16086098891", "1608609889…
# $ date          <dttm> 2017-05-01 14:35:14, 2017-04-21 22:01:40, 2017-03-24 01…
# $ type          <fct> received, received, sent, received, received, received, …
# $ body          <chr> "Test", "Test Message Please type YES if you receive thi…
# $ msg_type      <fct> imessage, imessage, sms, sms, sms, sms, sms, sms, sms, s…
# $ phone_type    <fct> ios, ios, android, android, android, android, android, a…

# %% [markdown]
# create new column freq_contacts: y/n

# %%
data <- data |> 
  mutate(
    freq_contacts = if_else(
      address %in% unlist(freq_contacts),
      "y", "n"
    ),
    freq_contacts = factor(freq_contacts)
  ) |> 
  glimpse()
# Out:
# Rows: 431,519
# Columns: 10
# $ subid         <dbl> 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,…
# $ freq_contacts <fct> n, n, y, y, y, y, y, y, y, y, y, y, y, y, y, y, y, y, y,…
# $ start_study   <dttm> 2017-03-02, 2017-03-02, 2017-03-24, 2017-03-24, 2017-03…
# $ end_study     <dttm> 2017-05-31, 2017-05-31, 2017-06-16, 2017-06-16, 2017-06…
# $ address       <chr> "16085720721", "16085722496", "16086098891", "1608609889…
# $ date          <dttm> 2017-05-01 14:35:14, 2017-04-21 22:01:40, 2017-03-24 01…
# $ type          <fct> received, received, sent, received, received, received, …
# $ body          <chr> "Test", "Test Message Please type YES if you receive thi…
# $ msg_type      <fct> imessage, imessage, sms, sms, sms, sms, sms, sms, sms, s…
# $ phone_type    <fct> ios, ios, android, android, android, android, android, a…

# %% [markdown]
# ## EDA on Contact
#
# frequent contact baesd on self-reports

# %%
data |> 
  ggplot(aes(x = freq_contacts)) +
  geom_bar() +
  facet_wrap(~subid)
